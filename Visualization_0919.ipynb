# %% [markdown]
# If we want to visualize a data set, which questions do we ask?

# %%
import pandas
iris = pandas.read_csv('~/Dropbox/datasets/iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# ### Which species has the largest petal lengths?

# %%
iris.groupby('Species').mean()
# Out:
#             SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# setosa            5.006       3.428        1.462       0.246
# versicolor        5.936       2.770        4.260       1.326
# virginica         6.588       2.974        5.552       2.026

# %% [markdown]
# ### How do petal lengths relate to petal widths?

# %% [markdown]
# Important questions:
#
# - What are the variables involved?   petal length, petal width.
# - What are the variable types? **numerical** and **numercial**.  Therefore, a good plot is the scatter plot.
#
# Visualization in Python.
#
# - Not perfect. No one solution that solves everything.
# - Good packages: seaborn, plotly, pandas (basic plots).
# - Many good (easy to use API) packages are built on top of matplotlib.

# %%
from matplotlib import pyplot
iris.plot.scatter(x='PetalWidth', y='PetalLength')
pyplot.show()

# %% [markdown]
# Same question but for different species.
#
# We have another variable: Species.  This is a **categorical** variable.

# %%
setosa, versicolor, virginica = iris[ iris.Species=='setosa' ], iris[ iris.Species=='versicolor'], iris[ iris.Species=='virginica']

# %%
ax = setosa.plot.scatter(x='PetalWidth', y='PetalLength', label='Setosa', color='Red')
ax = versicolor.plot.scatter(x='PetalWidth', y='PetalLength', label='Versicolor', color='Blue', ax=ax)
ax = virginica.plot.scatter(x='PetalWidth', y='PetalLength', label='Virginica', color='Green', ax=ax)

# %%
import seaborn
seaborn.relplot(x='PetalWidth', y='PetalLength', hue='Species', data=iris)

# %%
seaborn.relplot(x='PetalWidth', y='PetalLength', hue='Species', size=5*iris.SepalLength, data=iris)

# %%
seaborn.__version__
# Out:
# '0.9.0'

# %%
seaborn.lmplot(x='PetalWidth', y='PetalLength', hue='Species', data=iris)
pyplot.savefig('test.png')

# %% [markdown]
# ## Explore relationships between two numerical variables

# %% [markdown]
# - load tips dataset into a dataframe called "tips"
# -

# %%
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
seaborn.relplot(x='SepalLength', y='SepalWidth', data=iris)

# %%
tips = pandas.read_csv('~/Dropbox/datasets/tips.csv')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
seaborn.relplot(x='total_bill', y='tip', data=tips)

# %% [markdown]
# Do women tip more than men?

# %%
seaborn.relplot(x='total_bill', y='tip', hue='sex', data=tips)

# %%
tips[ tips.sex == 'Male'].mean()
# Out:
# total_bill    20.744076
# tip            3.089618
# size           2.630573
# dtype: float64

# %%
tips[ tips.sex == 'Female'].mean()
# Out:
# total_bill    18.056897
# tip            2.833448
# size           2.459770
# dtype: float64

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %% [markdown]
# ## Categorical vs Numerical variables
#
# For each category (x-axis) show statistics of y.

# %%
seaborn.boxplot(x='sex', y='tip', data=tips)

# %%
seaborn.violinplot(y='sex', x='tip', data=tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['normalized_tip'] = tips.tip / tips.total_bill

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  normalized_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2        0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3        0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3        0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2        0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4        0.146808

# %%
seaborn.boxplot(x='sex', y='normalized_tip', data=tips)

# %%
iris.head(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa

# %%
seaborn.relplot(x='PetalWidth', y='PetalLength', data=iris)

# %%
seaborn.distplot(iris.PetalWidth)

# %%
seaborn.jointplot(x='PetalWidth', y='PetalLength', data=iris)

# %%
seaborn.jointplot(x='PetalWidth', y='PetalLength', kind='kde', data=iris)

# %%
seaborn.relplot(x='PetalWidth', y='PetalLength', col='Species', hue='Species', style='Species', data=iris)

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  normalized_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2        0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3        0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3        0.166587

# %%
seaborn.lmplot(x='total_bill', y='tip', col='sex', row='smoker', data=tips)

# %%
seaborn.boxenplot(x='smoker', y='normalized_tip', hue='sex', data=tips)

# %%
seaborn.violinplot(x='smoker', y='normalized_tip', hue='sex', data=tips)

# %%
seaborn.boxplot(x='smoker', y='normalized_tip', hue='sex', data=tips)

# %%
seaborn.distplot(tips.tip)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  normalized_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2        0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3        0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3        0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2        0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4        0.146808

# %%
tips[['tip', 'sex']].plot.hist()

# %%
seaborn.FacetGrid(tips, col='sex')

# %%
ax = seaborn.distplot(tips[ tips.sex=='Male'].tip, label='Male')
seaborn.distplot(tips[ tips.sex=='Female'].tip, label='Female', ax=ax)

# %%
ax
